# %%
#All available utilities
dbutils.help()

# %%
#File System Utilities
dbutils.fs.help()

# %%
#display(dbutils.fs.ls("/databricks-datasets/airlines/"))
display(dbutils.fs.ls("/Volumes/catalog_s/default/data/sales/"))

# %%
display(dbutils.fs.head("/Volumes/catalog_s/default/data/sales/sales.csv"))

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("Input_cust_id", '20000', 'Customer ID')

# %%
dbutils.widgets.get("Input_cust_id")

# %%
# %sql
select ${Input_cust_id}

# %%
#secrets
dbutils.secrets.help()

# %%
#Notebooks
dbutils.notebook.help()
